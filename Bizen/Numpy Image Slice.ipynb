# %%
from scipy import misc

# %%
import matplotlib.pyplot as pit

# %%
dir (misc)
# Out:
# ['Tester',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '_info',
#  'absolute_import',
#  'ascent',
#  'bytescale',
#  'central_diff_weights',
#  'comb',
#  'derivative',
#  'division',
#  'doccer',
#  'face',
#  'factorial',
#  'factorial2',
#  'factorialk',
#  'fromimage',
#  'imfilter',
#  'imread',
#  'imresize',
#  'imrotate',
#  'imsave',
#  'imshow',
#  'info',
#  'lena',
#  'logsumexp',
#  'pade',
#  'print_function',
#  'source',
#  'test',
#  'toimage',
#  'who']

# %%
face = misc.face()

# %%
face.size
# Out:
# 2359296

# %%
face.shape
# Out:
# (768, 1024, 3)

# %%
face.size
# Out:
# 2359296

# %%
////Shows Dimension of a array////
# Out:
#   File "<ipython-input-17-dbd909b91ac0>", line 1
#     (///Shows, Dimension, of, a, array////)
#       ^
# SyntaxError: invalid syntax

# %%
face.ndim
# Out:
# 3

# %%
face
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
#         ...,
#         [120, 156,  95],
#         [119, 155,  93],
#         [118, 154,  92]]], dtype=uint8)

# %%
# %matplotlib

# %%
pit.imshow(face)

# %%
face[0]
# Out:
# array([[121, 112, 131],
#        [138, 129, 148],
#        [153, 144, 165],
#        ...,
#        [119, 126,  74],
#        [131, 136,  82],
#        [139, 144,  90]], dtype=uint8)

# %%
face[0].ndim
# Out:
# 2

# %%
pit.imshow(face[0:50])

# %%
face[0:50]
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#        [[168, 167, 181],
#         [164, 163, 177],
#         [159, 157, 171],
#         ...,
#         [ 38,  46,  31],
#         [ 39,  47,  32],
#         [ 39,  47,  32]],
#
#        [[152, 154, 169],
#         [148, 147, 163],
#         [135, 134, 150],
#         ...,
#         [ 44,  50,  36],
#         [ 43,  50,  34],
#         [ 43,  50,  34]],
#
#        [[135, 134, 150],
#         [135, 134, 150],
#         [138, 135, 152],
#         ...,
#         [ 41,  48,  32],
#         [ 45,  52,  36],
#         [ 47,  54,  36]]], dtype=uint8)

# %%
face[0:50,0:50]
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [120, 116, 131],
#         [122, 123, 143],
#         [143, 144, 164]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [128, 124, 139],
#         [135, 136, 154],
#         [136, 137, 155]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [154, 150, 165],
#         [118, 119, 137],
#         [ 99, 100, 118]],
#
#        ...,
#        [[168, 167, 181],
#         [164, 163, 177],
#         [159, 157, 171],
#         ...,
#         [145, 143, 157],
#         [150, 144, 158],
#         [151, 145, 159]],
#
#        [[152, 154, 169],
#         [148, 147, 163],
#         [135, 134, 150],
#         ...,
#         [149, 145, 159],
#         [137, 136, 144],
#         [142, 141, 149]],
#
#        [[135, 134, 150],
#         [135, 134, 150],
#         [138, 135, 152],
#         ...,
#         [100,  96, 110],
#         [ 80,  77,  86],
#         [ 83,  80,  89]]], dtype=uint8)

# %%
pit.imshow(face[0:50,0:50])

# %%
face[400:600]
# Out:
# array([[[138, 142,  92],
#         [146, 153, 102],
#         [157, 164, 113],
#         ...,
#         [ 27,  36,  17],
#         [ 26,  37,  20],
#         [ 26,  37,  20]],
#
#        [[134, 138,  88],
#         [140, 144,  94],
#         [142, 149,  98],
#         ...,
#         [ 30,  39,  20],
#         [ 26,  35,  16],
#         [ 20,  32,  12]],
#
#        [[145, 147,  98],
#         [142, 144,  95],
#         [136, 140,  90],
#         ...,
#         [ 31,  41,  17],
#         [ 30,  40,  16],
#         [ 28,  38,  14]],
#
#        ...,
#        [[169, 219, 108],
#         [170, 219, 110],
#         [160, 207, 103],
#         ...,
#         [117, 147,  93],
#         [116, 146,  92],
#         [116, 147,  90]],
#
#        [[168, 217, 110],
#         [167, 216, 111],
#         [154, 200, 101],
#         ...,
#         [114, 142,  91],
#         [115, 144,  90],
#         [115, 144,  90]],
#
#        [[168, 216, 114],
#         [166, 212, 113],
#         [149, 194,  99],
#         ...,
#         [113, 140,  89],
#         [114, 141,  90],
#         [115, 142,  91]]], dtype=uint8)

# %%
pit.imshow(face[400:600,600:800])

# %%
p_image = face[400:600,600:800]

# %%
p_image > 200
# Out:
# array([[[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False,  True, False],
#         [False,  True, False],
#         [False,  True, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False,  True, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        ...,
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]],
#
#        [[False, False, False],
#         [False, False, False],
#         [False, False, False],
#         ...,
#         [False, False, False],
#         [False, False, False],
#         [False, False, False]]], dtype=bool)

# %%
p_image[p_image > 200] = 255

# %%
pit.imshow(p_image)
